# %% [markdown]
# # 데이터 시각화(기본그래프)

# %% [markdown]
# ### matplotlib
# 파이썬에서 데이터를 효과적으로 시각화하기위해 만든 라이브러리
#
# 가장 많이 쓰는 라이브러리

# %% [markdown]
# ### 그래프의 기본적인 용어

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Figure
#
# Figure는 그림이 그려지는 일종의 도화지
#
# 우선 Figure를 그린 후, plt.subplots로 도화지를 분할해 각 부분에 그래프를 그리는 방식으로 진행

# %% [markdown]
# ### Axes
# Axes는 plot이 그려지는 공간

# %% [markdown]
# ### Axis
# plot의 축

# %% [markdown]
# ## 선그래프(Y축 데이터만 있는 경우 그래프 그리기)

# %%
import matplotlib.pyplot as plt

# %%
data1 = [10,14,19,20,25]

# %%
plt.plot(data1)

# %%
plt.plot(data1)
plt.show()

# %% [markdown]
# ## 선그래프(X,Y축 값이 모두 있는 경우 그래프 그리기)

# %%
import numpy as np

x = np.arange(-4.5,5,0.5)
y = 2*x**2
[x,y]
# Out:
# [array([-4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,  0.5,
#          1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5]),
#  array([40.5, 32. , 24.5, 18. , 12.5,  8. ,  4.5,  2. ,  0.5,  0. ,  0.5,
#          2. ,  4.5,  8. , 12.5, 18. , 24.5, 32. , 40.5])]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## 여러그래프그리기

# %%
import numpy as np

x = np.arange(-4.5,5,0.5)
y1 = 2*x**2
y2 = 5*x + 30
y3 = 4*x**2 + 10

# %%
import matplotlib.pyplot as plt

plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.show()

# %%
plt.plot(x,y1)

plt.figure()
plt.plot(x,y2)

plt.show()

# %% [markdown]
# ## 그래프 색상,선스타일,마커 지정하기

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
 x = np.arange(0,5,1)
 y1 = x
 y2 = x + 1
 y3 = x + 2
 y4 = x + 3

# %%
plt.plot(x,y1,y2,x,y3,x,y4)
plt.show()

# %%
plt.plot(x,y1,'-',x,y2,'--',x,y3,':',x,y4,'-.')
plt.show()

# %% [markdown]
# #### line
#
# 선 기호 | 선 모양
# :---|:---
# '-' | solid
# '--' | dashed
# '-.' | dash_dot
# ':' | dotted
# '' | draw nothing

# %%
plt.plot(x,y1,'m',x,y2,'y',x,y3,'k',x,y4,'c')
plt.show()

# %% [markdown]
# #### color
#
# * Pre-Defined color
#
# 컬러 기호| 컬러
# :---|:---
# b| blue
# g| green
# r| red
# c| cyan
# m| magenta
# y| yellow
# k| black
# w| white

# %%
plt.plot(x,y1,'o',x,y2,'^',x,y3,'s',x,y4,'d')
plt.show()

# %% [markdown]
# #### 마커지정
#
#
#
# 마커 약어| 마커
# :---|:---
# o| 원모양
# ^,v,<,>| 삼각형 위쪽,아래쪽,왼쪽,오른쪽
# s| 사각형
# p| 오각형
# h,H| 육각형
# *| 별모양
# +| 더하기
# d,D| 다아이몬드

# %% [markdown]
# ## 산점도

# %%
import matplotlib.pyplot as plt

# %%
height= [165,177,160,180,185,155,172]
weight=  [62,67,55,74,90,43,64]

plt.scatter(height,weight)
plt.xlabel('Height(m)')
plt.ylabel('Weight(Kg)')
plt.title('Height & Weight')
plt.grid(True)

# %%
plt.scatter(height,weight,s=500,c='r')
plt.show()

# %%
size = 100 *np.arange(1,8)
colors = ['r','g','b','c','m','k','y']

plt.scatter(height,weight, s=size, c=colors)
plt.show()

# %% [markdown]
# ## 막대그래프

# %%
members_IDs = ['m_01','m_02','m_03','m_04']
before_ex = [27, 35, 40, 33]
after_ex = [30,38,42, 37]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n_data = len(members_IDs)
index = np.arange(n_data)
plt.bar(index,before_ex)
plt.show()

# %%
plt.bar(index,before_ex,tick_label = members_IDs,width = 0.6)
plt.show()

# %% [markdown]
# ## 히스토그램

# %% [markdown]
# ### 히스토그램
# 데이터를 정해진 간격으로 나눈 후 그 간격안에 들어간 데이터 개수를 막대 그래프로 표시한 그래프
#
# 데이터가 어떤 분포를 갖는지 볼 때 주로 이용
#
# 히스토그램의 기본형식은  plt .hist ( x, [bins_n혹은 'auto'])

# %%
import matplotlib.pyplot as plt

# %%
math = [76,82,84,83,90,86,85,92,72,71,100,87,81,76,94,78,81,60,79,69,74,87,82,68,79]
plt.hist(math)
# Out:
# (array([1., 0., 3., 2., 5., 5., 5., 1., 2., 1.]),
#  array([ 60.,  64.,  68.,  72.,  76.,  80.,  84.,  88.,  92.,  96., 100.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(math,bins=8)
plt.show()

# %%
plt.hist(math,bins=8)
plt.xlabel('score')
plt.ylabel('frequency')
plt.title('histogram of math exam')
plt.grid()
plt.show()

# %% [markdown]
# ## 파이 그래프

# %% [markdown]
# 파이 그래프의 형식
#
# plt. pie (x, [,labels = label_seq, autopct='비율표시형식(ex:%0.1f)',
#
# shadow = False(기본)혹은 True, explode = explode_seq,
#
# counterclock = True 혹은 False, startangle = 각도 (기본은 0)

# %%
fruit = ['apple','banan','strawberry','orange','grape']
result = [7,6,3,2,2,]

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(result)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(result)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(result,labels=fruit,autopct='%.1f%%')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.pie(result,labels=fruit,autopct='%.1f%%',startangle=90,counterclock=False)
plt.show()

# %%
explode_value = (0.1,0,0,0,0)
plt.figure(figsize=(5,5))
plt.pie(result,labels=fruit,autopct='%.1f%%',startangle=90,counterclock = False,
        explode=explode_value,shadow=True)
plt.show()
